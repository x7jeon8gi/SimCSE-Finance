# %%
import pandas as pd

a = pd.read_pickle('./workspace/txt_pkl_v3/20220519.pkl')

# %%
a.head()
# Out:
#      주가번호                                                텍스트
# 0  787139  BGF리테일에 대해 투자의견 BUY와 목표주가 27만원으로 커버리지를 개시함. BG...
# 1  787133  BGF에 대해 투자의견 BUY와 목표주가 8,000원으로 커버리지를 개시함.BGF리...
# 2  787027  1Q22 실적은 매출액 3,950억원, 영업이익 1,815억원으로 사상 최대 실적을...
# 3  787300  [Semiconductor/equipment] Oversupply unlikely ...
# 4  787130  GS리테일에 대해 투자의견 BUY와 목표주가 3.4만원으로 분석을 시작함.GS리테일...

# %%
b = pd.read_pickle('./workspace/txt_pkl_v3/20220517.pkl')
b.head()
# Out:
#                                                       텍스트         0         1  \
# 주가번호
# 786865  BGF리테일 (282330) 모멘텀이 길어져요 BUY(Maintain)주가(5/17... -0.053928 -0.072178
# 786593  미주 시장에서 슈완스 브랜드의 점유율 상승, 그로서리/FS채널에서의 만두 입점률 확... -0.019571  0.009477
# 786864  CJ프레시웨이 (051500)BUY(Maintain)주가(5/17) 39,150원목... -0.050645 -0.053134
# 786578  2022.05.17 안정적 회복 궤도에 진입했음을 보여준 실적 1Q 실적은 매출 3... -0.050645 -0.053134
# 786463  CJ (001040/KS｜매수(유지)｜T.P 113,000원(유지))사회적 거리두기... -0.012944 -0.000107
#
#          2   3   4   5   6   7   8  ...  170  171  172  173  174  175  176  \
# 주가번호                                ...
# 786865 NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 786593 NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 786864 NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 786578 NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 786463 NaN NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
c = pd.read_pickle('./workspace/txt_pkl_v3/20171117.pkl')
c.head()
# Out:
#                                                       텍스트         0         1  \
# 주가번호
# 384746  AK홀딩스 : 유통을 제외한 전 계열사의 고른 성장 3Q17 연결 매출액 8,655...  0.009486 -0.010897
# 384531  CJ제일제당 (097950.KS)이익 가시성 점진적으로 개선 중 내년 영업이익 14...  0.011262  0.050275
# 384771  분기 실적 모멘텀은 둔화 2017년 11월 17일3Q17 실적 기대치 하회투자의견 ...  0.004988 -0.000988
# 384743  GS : 정유, 발전 사업 가치가 덜 반영됐다 3Q17 연결 매출액 4조2,229억...  0.003327  0.005919
# 384454  Daily News 2017년 11월 17일 4Q17 연결 매출액 1.6조원(+12... -0.004275 -0.022557
#
#                2         3         4         5         6         7         8  \
# 주가번호
# 384746   0.00235 -0.000995  0.015827  0.053647  0.039616  0.061623  0.084458
# 384531  0.045042  0.027619  0.019442   0.05454  0.049505  0.058051  0.065553
# 384771 -0.069662 -0.077763 -0.051172  0.038584  0.055054  0.027398  0.038309
# 384743 -0.005146 -0.000833  0.003467  0.023985  0.020611  0.019968  0.060428
# 384454 -0.017081 -0.036946 -0.047886 -0.003172  0.038144  0.076215  0.167289
#
# ...
